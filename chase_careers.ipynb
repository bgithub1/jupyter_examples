# %%
import pandas as pd
import numpy as np
import pypg.pg_pandas as pg
import os,sys
import pdb
import torch 
from torch import nn
from torch.autograd import Variable
from torch import optim
import torch.nn.functional as F
from dash.dependencies import Input, Output, State
# %matplotlib inline
import matplotlib.pyplot as plt
import plotly.plotly as py
import plotly.graph_objs as go

import numpy as np
import plotly.figure_factory as ff
import pandas as pd
import urllib.request
import scipy
# Out:
# /Users/bperlman1/Virtualenvs3/pyliverisk/lib/python3.6/site-packages/psycopg2/__init__.py:144: UserWarning: The psycopg2 wheel package will be renamed from release 2.8; in order to keep installing from binary please use "pip install psycopg2-binary" instead. For details see: <http://initd.org/psycopg/docs/install.html#binary-install-from-pypi>.
#   """)

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df_chase_begin = pd.read_csv('/Users/bperlman1/Documents/billybyte/qbpython/selaccess/selaccess/temp_folder/chase_jobs_njc.csv')
df_chase_begin['title'] = df_chase_begin.description.apply(lambda v: v.split('Req')[0].replace('\n',''))
print(f'total before duplicate drop: {len(df_chase_begin)}')
df_chase = df_chase_begin.drop_duplicates(subset=['req'])
# Out:
# total before duplicate drop: 1080

# %%
df_chase_begin[['req','title']].sort_values('req')
# Out:
#                    req                                        title
# 95    Req #: 180097014  Data Science/Machine Learning Engineer
# 755   Req #: 180097014  Data Science/Machine Learning Engineer
# 665   Req #: 180097014  Data Science/Machine Learning Engineer
# 635   Req #: 180097014  Data Science/Machine Learning Engineer
# 965   Req #: 180097014  Data Science/Machine Learning Engineer
# 155   Req #: 180097014  Data Science/Machine Learning Engineer
# 245   Req #: 180097014  Data Science/Machine Learning Engineer
# 425   Req #: 180097014  Data Science/Machine Learning Engineer
# 935   Req #: 180097014  Data Science/Machine Learning Engineer
# 695   Req #: 180097014  Data Science/Machine Learning Engineer
# 35    Req #: 180097014  Data Science/Machine Learning Engineer
# 1055  Req #: 180097014  Data Science/Machine Learning Engineer
# 515   Req #: 180097014  Data Science/Machine Learning Engineer
# 845   Req #: 180097014  Data Science/Machine Learning Engineer
# ...

# %%
df_chase[['req','title']]
# Out:
#                    req  \
# 0   Req #: 190022396
# 1   Req #: 180098045
# 2   Req #: 190021424
# 3   Req #: 190016947
# 4   Req #: 190029248
# 5   Req #: 190029241
# 6   Req #: 190027155
# 7   Req #: 190029194
# 8   Req #: 190037077
# 9   Req #: 190023527_3
# 10  Req #: 190038981
# 11  Req #: 190039921
# 12  Req #: 190034190
# 13  Req #: 190039606
# 14  Req #: 180123867
# 15  Req #: 190043296
# 16  Req #: 190042494
# 17  Req #: 190036596
# 18  Req #: 190037132
# 19  Req #: 190037118_1
# 20  Req #: 190037130_1
# 21  Req #: 190014606
# 22  Req #: 190020275
# 23  Req #: 190034444
# 24  Req #: 190029242
# 25  Req #: 190041635
# 26  Req #: 190027169
# 27  Req #: 190025214
# 28  Req #: 190030429
# 29  Req #: 190037224
# 30  Req #: 190037067
# 31  Req #: 190042783
# 32  Req #: 190029889
# 33  Req #: 190041393
# 34  Req #: 190041113
# 35  Req #: 180097014
# 36  Req #: 190029574
# 37  Req #: 190005912
# 38  Req #: 190014650
# 39  Req #: 190040736
# 40  Req #: 190040729
# 41  Req #: 190040742
# ...

# %%
words_to_search = ['tech','soft','support','wealth']
tech_indices = df_chase[df_chase.title.str.lower().str.contains('|'.join(words_to_search))].index
df_chase_tech = df_chase.loc[tech_indices]
df_chase_tech[['req','title']]
# Out:
#                    req  \
# 0   Req #: 190022396
# 2   Req #: 190021424
# 3   Req #: 190016947
# 8   Req #: 190037077
# 10  Req #: 190038981
# 11  Req #: 190039921
# 13  Req #: 190039606
# 16  Req #: 190042494
# 18  Req #: 190037132
# 19  Req #: 190037118_1
# 20  Req #: 190037130_1
# 21  Req #: 190014606
# 22  Req #: 190020275
# 28  Req #: 190030429
# 29  Req #: 190037224
# 30  Req #: 190037067
# 32  Req #: 190029889
# 37  Req #: 190005912
# 39  Req #: 190040736
# 40  Req #: 190040729
# 41  Req #: 190040742
# 42  Req #: 190019810
# 47  Req #: 190023457
# 52  Req #: 190013069
# 58  Req #: 190039298
#
#                                                                                                 title
# 0   VP, Software Engineering – Agile Coach
# 2   Software Engineer
# 3   Software Engineer, Infrastructure C#
# 8   Software Engineer- Big Data
# 10  Associate, Software Engineer
# 11  Associate, Software Engineering
# 13  Global Technology Infrastructure Workforce Evolution - Assoc
# ...

# %%
support_indices = df_chase[df_chase.title.str.lower().str.contains('|'.join(['support']))].index
df_chase_support = df_chase.loc[support_indices]
df_chase_support[['req','title']]
# Out:
# Empty DataFrame
# Columns: [req, title]
# Index: []

# %%
# Out:
#                  req  \
# 0   Req #: 190029164
# 2   Req #: 190019396
# 3   Req #: 190019391
# 6   Req #: 180111892
# 7   Req #: 190042720
# 27  Req #: 190043070
# 37  Req #: 190032657
# 43  Req #: 190006768
# 51  Req #: 190018608
#
#                                                                                                       title
# 0   Lead Software Engineer (Java/HTML) - Digital Technology
# 2   Java Software Engineer (Hadoop and Big Data) - Digital Technology
# 3   Java Software Engineer (Hadoop and Big Data) - Digital Technology
# 6   Software Engineering Lead (Pega)
# 7   Associate, Commercial Banker - Middle Market & Specialized Industries - Technology Group - New York, NY
# 27  Assocate - Technical support
# 37  Mobile Software Engineer - Developer Lead
# 43  Software Engineer for FX Options Technology
# 51  Senior Cyber Security Incident Response/ Attack Analysis Technical Lead- VP

# %%
for s in df_chase_tech.loc[47].description.split('\n'):
    print(s)
# Out:
# FX Algo Java Software Engineer
# Req #: 190023457
# Location: Jersey City, NJ, US
# Job Category: Technology
# Job Description:
# Our Corporate & Investment Bank relies on innovators like you to build and maintain the technology that helps us safely service the world’s important corporations, governments and institutions. You’ll develop solutions for a bank entrusted with holding $18 trillion of assets and $393 billion in deposits.  CIB provides strategic advice, raises capital, manages risk, and extends liquidity in markets spanning over 100 countries around the world.
#
# ...
